# %%
import pandas as pd

# %%
date = pd.read_csv("./data/date.csv", compression='gzip', sep=';', encoding='utf-8')
card = pd.read_csv("./data/card.csv", compression='gzip', sep=';', encoding='utf-8')
seller = pd.read_csv("./data/seller.csv", compression='gzip', sep=';', encoding='utf-8')
card_stats = pd.read_csv("./data/card_stats.csv", compression='gzip', sep=';', encoding='utf-8')
sale_offer = pd.read_csv("./data/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8')

# %%
new_offers = pd.read_csv("./data/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8')
new_offers
# Out:
#           id  seller_id   price  card_id card_condition card_language  \
# 0          1         11    0.35        1      Near Mint     S-Chinese
# 1          2       7083    0.38        1      Near Mint       English
# 2          3         28    0.40        1      Near Mint       English
# 3          4         47    0.47        1           Mint       English
# 4          5       4895    0.50        1      Near Mint       English
# ...      ...        ...     ...      ...            ...           ...
# 67274  67275        474   34.85      264      Near Mint       English
# 67275  67276       2557   34.90      264      Near Mint       English
# 67276  67277        191   34.99      264      Near Mint       English
# 67277  67278       4808   49.00      264           Mint       English
# 67278  67279        168  110.00      264      Near Mint      Japanese
#
#        is_foiled  amount  date_id
# 0          False       3       39
# 1          False       5       39
# 2          False       1       39
# 3          False       1       39
# 4          False       1       39
# ...          ...     ...      ...
# 67274       True       1       39
# 67275       True       4       39
# 67276       True       1       39
# 67277       True       2       39
# 67278       True       1       39
#
# [67279 rows x 9 columns]

# %%
old = pd.read_csv("./.data/sale_offer.csv", compression='gzip', sep=';', encoding="utf-8")
old
# Out:
#               id  seller_id   price  card_id card_condition card_language  \
# 0              1          2    0.15        1           Mint       English
# 1              2          5    0.25        1      Excellent     S-Chinese
# 2              3       6146    0.25        1      Near Mint       English
# 3              4         13    0.35        1      Near Mint       English
# 4              5        291    0.39        1      Near Mint       English
# ...          ...        ...     ...      ...            ...           ...
# 3337702  3337703        474   34.85      264      Near Mint       English
# 3337703  3337704       2557   34.90      264      Near Mint       English
# 3337704  3337705        191   34.99      264      Near Mint       English
# 3337705  3337706       4808   49.00      264           Mint       English
# 3337706  3337707        168  110.00      264      Near Mint      Japanese
#
#          is_foiled  amount  date_id
# 0            False       1        1
# 1            False       1        1
# 2            False       2        1
# 3            False       1        1
# 4            False       1        1
# ...            ...     ...      ...
# 3337702       True       1       38
# 3337703       True       4       38
# 3337704       True       1       38
# 3337705       True       2       38
# 3337706       True       1       38
#
# [3337707 rows x 9 columns]

# %%
added_card_ids = list(new_offers['card_id'].unique())
tb_dropped = old[old['card_id'].isin(added_card_ids)
                    & (old['date_id'] == 39)].index
old = old.drop(tb_dropped)
old
# Out:
#               id  seller_id   price  card_id card_condition card_language  \
# 0              1          2    0.15        1           Mint       English
# 1              2          5    0.25        1      Excellent     S-Chinese
# 2              3       6146    0.25        1      Near Mint       English
# 3              4         13    0.35        1      Near Mint       English
# 4              5        291    0.39        1      Near Mint       English
# ...          ...        ...     ...      ...            ...           ...
# 3337702  3337703        474   34.85      264      Near Mint       English
# 3337703  3337704       2557   34.90      264      Near Mint       English
# 3337704  3337705        191   34.99      264      Near Mint       English
# 3337705  3337706       4808   49.00      264           Mint       English
# 3337706  3337707        168  110.00      264      Near Mint      Japanese
#
#          is_foiled  amount  date_id
# 0            False       1        1
# 1            False       1        1
# 2            False       2        1
# 3            False       1        1
# 4            False       1        1
# ...            ...     ...      ...
# 3337702       True       1       38
# 3337703       True       4       38
# 3337704       True       1       38
# 3337705       True       2       38
# 3337706       True       1       38
#
# [3337707 rows x 9 columns]

# %%
# Merge new offers with previous ones and refresh the index and id
old = pd.concat([old, new_offers]).reset_index(drop=True)
old.index += 1
old["id"] = old.index
old
# Out:
#               id  seller_id   price  card_id card_condition card_language  \
# 1              1          2    0.15        1           Mint       English
# 2              2          5    0.25        1      Excellent     S-Chinese
# 3              3       6146    0.25        1      Near Mint       English
# 4              4         13    0.35        1      Near Mint       English
# 5              5        291    0.39        1      Near Mint       English
# ...          ...        ...     ...      ...            ...           ...
# 3404982  3404982        474   34.85      264      Near Mint       English
# 3404983  3404983       2557   34.90      264      Near Mint       English
# 3404984  3404984        191   34.99      264      Near Mint       English
# 3404985  3404985       4808   49.00      264           Mint       English
# 3404986  3404986        168  110.00      264      Near Mint      Japanese
#
#          is_foiled  amount  date_id
# 1            False       1        1
# 2            False       1        1
# 3            False       2        1
# 4            False       1        1
# 5            False       1        1
# ...            ...     ...      ...
# 3404982       True       1       39
# 3404983       True       4       39
# 3404984       True       1       39
# 3404985       True       2       39
# 3404986       True       1       39
#
# [3404986 rows x 9 columns]

# %%
sale_offer = old
sale_offer
# Out:
#               id  seller_id   price  card_id card_condition card_language  \
# 1              1          2    0.15        1           Mint       English
# 2              2          5    0.25        1      Excellent     S-Chinese
# 3              3       6146    0.25        1      Near Mint       English
# 4              4         13    0.35        1      Near Mint       English
# 5              5        291    0.39        1      Near Mint       English
# ...          ...        ...     ...      ...            ...           ...
# 3404982  3404982        474   34.85      264      Near Mint       English
# 3404983  3404983       2557   34.90      264      Near Mint       English
# 3404984  3404984        191   34.99      264      Near Mint       English
# 3404985  3404985       4808   49.00      264           Mint       English
# 3404986  3404986        168  110.00      264      Near Mint      Japanese
#
#          is_foiled  amount  date_id
# 1            False       1        1
# 2            False       1        1
# 3            False       2        1
# 4            False       1        1
# 5            False       1        1
# ...            ...     ...      ...
# 3404982       True       1       39
# 3404983       True       4       39
# 3404984       True       1       39
# 3404985       True       2       39
# 3404986       True       1       39
#
# [3404986 rows x 9 columns]

# %%
card.to_csv("./.pickles/card.csv", compression='gzip', sep=';', index=False, encoding='utf-8')
date.to_csv("./.pickles/date.csv", compression='gzip', sep=';', index=False, encoding='utf-8')
seller.to_csv("./.pickles/seller.csv", compression='gzip', sep=';', index=False, encoding='utf-8')
card_stats.to_csv("./.pickles/card_stats.csv", compression='gzip', sep=';', index=False, encoding='utf-8')
sale_offer.to_csv("./.pickles/sale_offer.csv", compression='gzip', sep=';', index=False, encoding='utf-8')

# %%
date = pd.read_csv("./.pickles/date.csv", compression='gzip', sep=';', encoding='utf-8')
card = pd.read_csv("./.pickles/card.csv", compression='gzip', sep=';', encoding='utf-8')
seller = pd.read_csv("./.pickles/seller.csv", sep=';', compression='gzip', encoding='utf-8')
card_stats = pd.read_csv("./.pickles/card_stats.csv", compression='gzip', sep=';', encoding='utf-8')
sale_offer = pd.read_csv("./.pickles/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8')

# %%
sale_offer
# Out:
#               id  seller_id   price  card_id card_condition card_language  \
# 0              1          2    0.15        1           Mint       English
# 1              2          5    0.25        1      Excellent     S-Chinese
# 2              3       6146    0.25        1      Near Mint       English
# 3              4         13    0.35        1      Near Mint       English
# 4              5        291    0.39        1      Near Mint       English
# ...          ...        ...     ...      ...            ...           ...
# 3404981  3404982        474   34.85      264      Near Mint       English
# 3404982  3404983       2557   34.90      264      Near Mint       English
# 3404983  3404984        191   34.99      264      Near Mint       English
# 3404984  3404985       4808   49.00      264           Mint       English
# 3404985  3404986        168  110.00      264      Near Mint      Japanese
#
#          is_foiled  amount  date_id
# 0            False       1        1
# 1            False       1        1
# 2            False       2        1
# 3            False       1        1
# 4            False       1        1
# ...            ...     ...      ...
# 3404981       True       1       39
# 3404982       True       4       39
# 3404983       True       1       39
# 3404984       True       2       39
# 3404985       True       1       39
#
# [3404986 rows x 9 columns]

# %%
date.to_pickle("./.pickles/date.pkl")
card.to_pickle("./.pickles/card.pkl")
seller.to_pickle("./.pickles/seller.pkl")
card_stats.to_pickle("./.pickles/card_stats.pkl")
sale_offer.to_pickle("./.pickles/sale_offer.pkl")
# Out:
# 990 µs ± 33.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.17 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.64 ms ± 214 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.87 ms ± 18.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 636 ms ± 8.72 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd

date = pd.read_pickle("./.pickles/date.pkl")
card = pd.read_pickle("./.pickles/card.pkl")
seller = pd.read_pickle("./.pickles/seller.pkl")
card_stats = pd.read_pickle("./.pickles/card_stats.pkl")
sale_offer = pd.read_pickle("./.pickles/sale_offer.pkl")

# %%
# %timeit sale_offer.to_csv("./.pickles/sale_offer.csv", compression='gzip', sep=';', index=False, encoding='utf-8')
# Out:
# 11.4 s ± 180 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit sale_offer.to_pickle("./.pickles/sale_offer.pkl")
# Out:
# 625 ms ± 27.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
date = pd.read_csv("./data/date.csv", compression='gzip', sep=';', encoding='utf-8')
card = pd.read_csv("./data/card.csv", compression='gzip', sep=';', encoding='utf-8')
seller = pd.read_csv("./data/seller.csv", compression='gzip', sep=';', encoding='utf-8')
card_stats = pd.read_csv("./data/card_stats.csv", compression='gzip', sep=';', encoding='utf-8')
sale_offer = pd.read_csv("./data/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8')

# %%
date.to_csv("./.data/date.csv", compression='gzip', sep=';', encoding='utf-8', index=False)
card.to_csv("./.data/card.csv", compression='gzip', sep=';', encoding='utf-8', index=False)
seller.to_csv("./.data/seller.csv", compression='gzip', sep=';', encoding='utf-8', index=False)
card_stats.to_csv("./.data/card_stats.csv", compression='gzip', sep=';', encoding='utf-8', index=False)
sale_offer.to_csv("./.data/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8', index=False)

# %%
pd.read_csv("./data/sale_offer.csv", compression='gzip', sep=';', encoding='utf-8')

# %%
offers = sale_offer[sale_offer['date_id'] > 34]
offers.groupby(['card_id', 'date_id']).count()
# Out:
#                   id  seller_id  price  card_condition  card_language  \
# card_id date_id
# 1       35       166        166    166             166            166
#         36       164        164    164             164            164
#         37       163        163    163             163            163
#         38       167        167    167             167            167
#         39       166        166    166             166            166
# ...              ...        ...    ...             ...            ...
# 264     35        32         32     32              32             32
#         36        32         32     32              32             32
#         37        32         32     32              32             32
#         38        32         32     32              32             32
#         39        32         32     32              32             32
#
#                  is_foiled  amount
# card_id date_id
# 1       35             166     166
#         36             164     164
#         37             163     163
#         38             167     167
#         39             166     166
# ...                    ...     ...
# 264     35              32      32
#         36              32      32
#         37              32      32
#         38              32      32
#         39              32      32
#
# [1319 rows x 7 columns]
